# %%
import os
import pandas as pd

# %%
path = os.path.join(os.path.join(os.getcwd(), "../nextbike/data"), "input/nuremberg.csv")
path
# Out:
# '/Users/mstroh/PycharmProjects/PDS_Project/notebooks/../nextbike/data/input/nuremberg.csv'

# %%
df = pd.read_csv(path)
# clean up useless index column
df = df.drop(df.columns[[0]], axis=1)
df
# Out:
#          p_spot  p_place_type             datetime  b_number   trip     p_uid  \
# 0          True             0  2019-01-20 02:06:00     11281  first   4774295
# 1          True             0  2019-01-20 14:16:00     11281   last   4774295
# 2          True             0  2019-01-20 00:00:00     11169  first   4774543
# 3          True             0  2019-01-20 01:55:00     11169  start   4774543
# 4          True             0  2019-01-20 02:06:00     11169    end   4774368
# ...         ...           ...                  ...       ...    ...       ...
# 2275084   False            12  2019-12-31 23:59:00     90483   last  26506255
# 2275085   False            12  2019-12-31 11:17:00     90057  first  26504052
# 2275086    True             0  2019-12-31 23:59:00     90057   last     66103
# 2275087    True             0  2019-12-31 17:00:00     90206  first     66119
# 2275088    True             0  2019-12-31 23:59:00     90206   last     66119
#
# ...

# %%
free_bikes = df[df['p_bike'] == True]
free_bikes
# Out:
#          p_spot  p_place_type             datetime  b_number   trip     p_uid  \
# 56        False            12  2019-01-20 19:04:00     11235    end  12118660
# 57        False            12  2019-01-20 21:03:00     11235  start  12118660
# 92        False            12  2019-01-20 10:13:00     11103    end  12108257
# 93        False            12  2019-01-20 16:05:00     11103  start  12108257
# 116       False            12  2019-01-20 00:00:00     11289  first  12094082
# ...         ...           ...                  ...       ...    ...       ...
# 2275081   False            12  2019-12-31 11:17:00     90483  first  26504049
# 2275082   False            12  2019-12-31 12:43:00     90483  start  26504888
# 2275083   False            12  2019-12-31 12:51:00     90483    end  26506255
# 2275084   False            12  2019-12-31 23:59:00     90483   last  26506255
# 2275085   False            12  2019-12-31 11:17:00     90057  first  26504052
#
# ...

# %%
fix_spots = df[df['p_spot'] == True]
fix_spots
# Out:
#          p_spot  p_place_type             datetime  b_number   trip    p_uid  \
# 0          True             0  2019-01-20 02:06:00     11281  first  4774295
# 1          True             0  2019-01-20 14:16:00     11281   last  4774295
# 2          True             0  2019-01-20 00:00:00     11169  first  4774543
# 3          True             0  2019-01-20 01:55:00     11169  start  4774543
# 4          True             0  2019-01-20 02:06:00     11169    end  4774368
# ...         ...           ...                  ...       ...    ...      ...
# 2275079    True             0  2019-12-31 17:06:00     90451    end    66112
# 2275080    True             0  2019-12-31 23:59:00     90451   last    66112
# 2275086    True             0  2019-12-31 23:59:00     90057   last    66103
# 2275087    True             0  2019-12-31 17:00:00     90206  first    66119
# 2275088    True             0  2019-12-31 23:59:00     90206   last    66119
#
# ...

# %%
# either p_bike or p_spot is set
# booleans for free bikes and fix spots
df[(df['p_bike'] == False) & (df['p_spot'] == False)]
# Out:
#          p_spot  p_place_type             datetime  b_number   trip     p_uid  \
# 158207    False             0  2019-05-10 14:34:00     11252  first  15576412
# 158208    False             0  2019-05-10 16:23:00     11252  start  15576412
# 520675    False             0  2019-01-20 00:00:00     90628  first    750382
# 520676    False             0  2019-01-20 23:59:00     90628   last    750382
# 521194    False             0  2019-01-21 00:00:00     90628  first    750382
# ...         ...           ...                  ...       ...    ...       ...
# 1780011   False             0  2019-06-03 23:59:00     90628   last    750382
# 1780023   False             0  2019-06-04 00:00:00     90628  first    750382
# 1780024   False             0  2019-06-04 10:16:00     90628  start    750382
# 1780025   False             0  2019-06-04 10:18:00     90628    end    750382
# 1780026   False             0  2019-06-04 11:32:00     90628   last    750382
#
# ...

# %%
# p_place_type is either 0 or 12
# fix spot => place_type: 0
# free bike => place_type: 12
df[(df['p_place_type'] != 0) & (df['p_place_type'] != 12)]
# Out:
# Empty DataFrame
# Columns: [p_spot, p_place_type, datetime, b_number, trip, p_uid, p_bikes, p_lat, b_bike_type, p_name, p_number, p_lng, p_bike]
# Index: []

# %%
# possible values for trip are:
# start, end, first, last
df.trip.unique()
# Out:
# array(['first', 'last', 'start', 'end'], dtype=object)

# %%
all_p_names = df.p_name.unique()
all_p_names
# Out:
# array(['Biegenstraße/Cineplex', 'Südbahnhof',
#        'Frankfurter Straße/Psychologie', ..., 'Bucher Str. 10',
#        'Nützelstr. 4', 'Bucher Str. 17'], dtype=object)

# %%
all_p_names.size
# Out:
# 2252

# %%
all_p_uids = df.p_uid.unique()
all_p_uids
# Out:
# array([ 4774295,  4774543,  4774368, ..., 26504888, 26506255, 26504052])

# %%
all_p_uids.size
# Out:
# 158375

# %%
df.drop_duplicates()
# Out:
#          p_spot  p_place_type             datetime  b_number   trip     p_uid  \
# 0          True             0  2019-01-20 02:06:00     11281  first   4774295
# 1          True             0  2019-01-20 14:16:00     11281   last   4774295
# 2          True             0  2019-01-20 00:00:00     11169  first   4774543
# 3          True             0  2019-01-20 01:55:00     11169  start   4774543
# 4          True             0  2019-01-20 02:06:00     11169    end   4774368
# ...         ...           ...                  ...       ...    ...       ...
# 1690185   False            12  2019-12-31 12:19:00     90467    end  26505408
# 1690193   False            12  2019-12-31 00:00:00     90022  first  26493105
# 1690246   False            12  2019-12-31 12:43:00     90483  start  26504888
# 1690248   False            12  2019-12-31 23:59:00     90483   last  26506255
# 1937553   False            12  2019-09-07 21:56:00     90364    end  21683684
#
# ...

# %%
print(df.p_lat.round(6)[0])
# Out:
# 50.808852

# %%
# 5 different types of bikes
all_b_bike_type = df.b_bike_type.unique()
all_b_bike_type
# Out:
# array([15,  0,  4, 71, 14])

# %%
df[df['p_uid'] == 4774295]
# Out:
#         p_spot  p_place_type             datetime  b_number   trip    p_uid  \
# 0         True             0  2019-01-20 02:06:00     11281  first  4774295
# 1         True             0  2019-01-20 14:16:00     11281   last  4774295
# 48        True             0  2019-01-20 15:14:00     11235    end  4774295
# 49        True             0  2019-01-20 15:23:00     11235  start  4774295
# 64        True             0  2019-01-20 13:41:00     11214    end  4774295
# ...        ...           ...                  ...       ...    ...      ...
# 520520    True             0  2019-12-31 23:59:00     11163   last  4774295
# 520523    True             0  2019-12-31 18:21:00     11079    end  4774295
# 520524    True             0  2019-12-31 18:23:00     11079  start  4774295
# 520577    True             0  2019-12-31 18:51:00     11299    end  4774295
# 520578    True             0  2019-12-31 21:44:00     11299   last  4774295
#
# ...

# %%
# i assume every p_uid is associated with a specific p_name
df[(df['p_uid'] == 4774295) & (df['p_name'] != 'Biegenstraße/Cineplex')]
# Out:
# Empty DataFrame
# Columns: [p_spot, p_place_type, datetime, b_number, trip, p_uid, p_bikes, p_lat, b_bike_type, p_name, p_number, p_lng, p_bike]
# Index: []

# %%
# kick out "duplicated" infos
df_cleaned = df.drop(['p_place_type', 'p_uid', 'p_bike'], axis=1)
df_cleaned
# Out:
#          p_spot             datetime  b_number   trip  p_bikes      p_lat  \
# 0          True  2019-01-20 02:06:00     11281  first        5  50.808852
# 1          True  2019-01-20 14:16:00     11281   last        4  50.808852
# 2          True  2019-01-20 00:00:00     11169  first        5  50.795224
# 3          True  2019-01-20 01:55:00     11169  start        5  50.795224
# 4          True  2019-01-20 02:06:00     11169    end        4  50.804522
# ...         ...                  ...       ...    ...      ...        ...
# 2275084   False  2019-12-31 23:59:00     90483   last        1  49.456960
# 2275085   False  2019-12-31 11:17:00     90057  first        0  49.456893
# 2275086    True  2019-12-31 23:59:00     90057   last        4  49.457127
# 2275087    True  2019-12-31 17:00:00     90206  first        6  49.448755
# 2275088    True  2019-12-31 23:59:00     90206   last        8  49.448755
#
#          b_bike_type                          p_name  p_number      p_lng
# ...

# %%
df_cleaned[df_cleaned['p_name'] == 'Südbahnhof']
# Out:
#         p_spot             datetime  b_number   trip  p_bikes      p_lat  \
# 2         True  2019-01-20 00:00:00     11169  first        5  50.795224
# 3         True  2019-01-20 01:55:00     11169  start        5  50.795224
# 38        True  2019-01-20 00:00:00     11235  first        5  50.795224
# 39        True  2019-01-20 08:06:00     11235  start        3  50.795224
# 151       True  2019-01-20 13:19:00     11127    end        1  50.795224
# ...        ...                  ...       ...    ...      ...        ...
# 520155    True  2019-12-31 10:12:00     11235  start        3  50.795224
# 520316    True  2019-12-31 00:00:00     11107  first        2  50.795224
# 520317    True  2019-12-31 17:03:00     11107  start        1  50.795224
# 520322    True  2019-12-31 00:00:00     11173  first        2  50.795224
# 520323    True  2019-12-31 10:12:00     11173  start        3  50.795224
#
#         b_bike_type      p_name  p_number     p_lng
# ...

# %%
# every p_name has the same p_number (exception: bikes!)
df_cleaned[df_cleaned['p_name'] == 'Südbahnhof'].p_number.unique()
# Out:
# array([5173.])

# %%
# one of the values of p_number is NaN
df_cleaned.p_number.unique().size
# Out:
# 102

# %%
df_cleaned.p_name.unique().size
# Out:
# 2252

# %%
df_cleaned.b_number.unique().size
# Out:
# 837

# %%
df_cleaned[(df_cleaned['b_number'] == 11169) & ((df_cleaned['trip'] == 'start') | (df_cleaned['trip'] == 'first'))]
# Out:
#         p_spot             datetime  b_number   trip  p_bikes      p_lat  \
# 2         True  2019-01-20 00:00:00     11169  first        5  50.795224
# 3         True  2019-01-20 01:55:00     11169  start        5  50.795224
# 5         True  2019-01-20 08:15:00     11169  start        3  50.804522
# 7         True  2019-01-20 11:58:00     11169  start        1  50.804522
# 9         True  2019-01-20 15:12:00     11169  start        3  50.804725
# ...        ...                  ...       ...    ...      ...        ...
# 519443   False  2019-12-29 15:56:00     11169  start        1  50.822274
# 519948   False  2019-12-30 00:00:00     11169  first        1  50.822274
# 520507   False  2019-12-31 00:00:00     11169  first        1  50.822274
# 520508   False  2019-12-31 14:59:00     11169  start        1  50.822274
# 520510    True  2019-12-31 23:39:00     11169  start        2  50.827921
#
#         b_bike_type                          p_name  p_number     p_lng
# ...

# %%
# first and last seems to mark the first and last activity of every day
# why is first and last not the same time as start and end???
# do we need these additional infos about first & last???
df_cleaned[(df_cleaned['b_number'] == 11169)].head(30)
# Out:
#       p_spot             datetime  b_number   trip  p_bikes      p_lat  \
# 2       True  2019-01-20 00:00:00     11169  first        5  50.795224
# 3       True  2019-01-20 01:55:00     11169  start        5  50.795224
# 4       True  2019-01-20 02:06:00     11169    end        4  50.804522
# 5       True  2019-01-20 08:15:00     11169  start        3  50.804522
# 6       True  2019-01-20 11:39:00     11169    end        1  50.804522
# 7       True  2019-01-20 11:58:00     11169  start        1  50.804522
# 8       True  2019-01-20 12:06:00     11169    end        2  50.804725
# 9       True  2019-01-20 15:12:00     11169  start        3  50.804725
# 10      True  2019-01-20 15:27:00     11169    end        5  50.822927
# 11      True  2019-01-20 15:39:00     11169  start        5  50.822927
# 12      True  2019-01-20 15:42:00     11169    end        4  50.822927
# 13      True  2019-01-20 16:40:00     11169   last        5  50.822927
# ...

# %%
df_geoloc = df_cleaned[['p_name', 'p_lat', 'p_lng']].drop_duplicates()
df_geoloc
# Out:
#                                    p_name      p_lat      p_lng
# 0                   Biegenstraße/Cineplex  50.808852   8.773134
# 2                              Südbahnhof  50.795224   8.763266
# 4          Frankfurter Straße/Psychologie  50.804522   8.770358
# 8                           Wilhelmsplatz  50.804725   8.759248
# 10       Alte Kasseler Straße/Jägertunnel  50.822927   8.774681
# ...                                   ...        ...        ...
# 1690178                        BIKE 90155  49.461240  11.056849
# 1690185                        BIKE 90467  49.454160  11.078513
# 1690246                        BIKE 90483  49.456587  11.088190
# 1690248                        BIKE 90483  49.456960  11.105922
# 1937553                        BIKE 90364  49.411742  11.297466
#
# [300739 rows x 3 columns]

# %%
path = os.path.join(os.path.join(os.getcwd(), "../nextbike/data"), "output/geoloc.csv")
path
# Out:
# '/Users/mstroh/PycharmProjects/PDS_Project/notebooks/../nextbike/data/output/geoloc.csv'

# %%
df_geoloc.to_csv(path, index=False)
