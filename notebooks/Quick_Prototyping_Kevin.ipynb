# %%
import pandas as pd
import os

# %%
path = os.getcwd()+"/../nextbike/data/output/trips.csv"
path
# Out:
# 'C:\\Users\\lenovo\\Documents\\GitHub\\Project\\notebooks/../nextbike/data/output/trips.csv'

# %%
df=pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0  p_spot_start  p_place_type_start           Start Time  \
# 0      210276          True                   0  2019-03-20 13:56:00
# 1      210277         False                  12  2019-04-12 08:25:00
# 2      210278         False                  12  2019-04-12 08:34:00
# 3      210279          True                   0  2019-01-22 07:30:00
# 4      210280          True                   0  2019-01-24 09:00:00
#
#    Bike Number  p_uid_start  p_bikes_start  Latitude_start  b_bike_type_start  \
# 0        90000        66128              5       49.435580                 71
# 1        90000     14394768              1       49.448249                 71
# 2        90000     14394887              1       49.448284                 71
# 3        90001       103596              1       49.440970                  4
# 4        90001       331990              5       49.428760                  4
#
#                         Place_start  ...  End Place_id  Longitude_end  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  p_place_type_start    Bike Number   p_uid_start  \
# count  186408.000000       186408.000000  186408.000000  1.864080e+05
# mean   308724.694423            8.404017   90252.191430  1.618946e+07
# std     56844.540499            5.497351     156.394462  1.015803e+07
# min    210276.000000            0.000000   90000.000000  6.609300e+04
# 25%    259516.750000            0.000000   90121.000000  1.134180e+05
# 50%    308728.500000           12.000000   90243.000000  2.137825e+07
# 75%    358046.250000           12.000000   90369.000000  2.358190e+07
# max    407529.000000           12.000000   90859.000000  2.651988e+07
#
#        p_bikes_start  Latitude_start  b_bike_type_start  Start Place_id  \
# count  186408.000000   186408.000000      186408.000000   186408.000000
# mean        2.436934       49.452338          63.653411     1412.908217
# std         2.956303        0.008749          20.795308     2397.581993
# ...
